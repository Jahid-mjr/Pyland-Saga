# %%
a = 10
print(a, "It is a number")
print(f"{a} is a number")
# Out:
# 10 It is a number
# 10 is a number

# %%
a = int(input("Enter a number: "))
b = int(input("Enter a number: "))
a+b
# Out:
# Enter a number: 45
# Enter a number: 85
# 130

# %%
print("I", "am", "jahid", sep = "#")
# Out:
# I#am#jahid

# %%
print("I", "am", "jahid", sep = ":)")
# Out:
# I:)am:)jahid

# %%
print("Jahid is me", end = " ")
print("Jahid is me")
# Out:
# Jahid is me Jahid is me

# %%
a = 10
if a > 20:
  print("a is less than 20")
  print(a)
print(a)
# Out:
# 10

# %%
b = int(input("Enter a number: "))
if b > 0:
  print("Positive")
elif b == 0:
  print("Zero")
else :
  print("Negative")
# Out:
# Enter a number: 5
# Positive

# %%
a = "Jahid"
#a[1]
a[-1]
# Out:
# 'd'

# %%
a = "i love coding"
d = a[-1 :: -1]
print(d)
# Out:
# gnidoc evol i

# %%
name = "Jahidul islam"
v = name.index("h")
print(v)
# Out:
# 2

# %%
x = name.upper()
x
# Out:
# 'JAHIDUL ISLAM'

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a = 0
while a < 100 :
  a += 1
  #print(a)

# %%
a = "I am Jahid"
b = 0
for i in a:
  b += 1

print(b)
# Out:
# 10

# %%
a= 0
while a< 12:
  a = a +1
  if a%2==0:
    print(a)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
