# %%
d = {1: "Jahid", 2:"Rayhan", 3:"Islam"}
d[1]
# Out:
# 'Jahid'

# %%
d.items()
# Out:
# dict_items([(1, 'Jahid'), (2, 'Rayhan'), (3, 'Islam')])

# %%
for i,j in d.items():
  print(f"key = {i}, value = {j}")
# Out:
# key = 1, value = Jahid
# key = 2, value = Rayhan
# key = 3, value = Islam
# key = 6, value = None
# key = 7, value = None
# key = 9, value = None

# %%
d.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
for i in d.keys():
  print(i)
# Out:
# 1
# 2
# 3

# %%
d.values()
# Out:
# dict_values(['Jahid', 'Rayhan', 'Islam'])

# %%
for i in d.values():
  print(i)
# Out:
# Jahid
# Rayhan
# Islam

# %%
e = {1: "Jahid", 2:"Rayhan", 3:"Islam"}
e.pop(1)
e
# Out:
# {2: 'Rayhan', 3: 'Islam'}

# %%
f = {1: "Jahid", 2:"Rayhan", 3:"Islam"}
f.popitem()
f
# Out:
# {1: 'Jahid', 2: 'Rayhan'}

# %%
g = {1: "Jahid", 2:"Rayhan", 3:"Islam"}
h = {4: "Jahid", 5:"Rayhan", 6:"Islam"}
g.update(h)
g
# Out:
# {1: 'Jahid', 2: 'Rayhan', 3: 'Islam', 4: 'Jahid', 5: 'Rayhan', 6: 'Islam'}

# %%
g
g[1]
g.get(1)
g.setdefault(8,"k")
g
# Out:
# {1: 'Jahid',
#  2: 'Rayhan',
#  3: 'Islam',
#  4: 'Jahid',
#  5: 'Rayhan',
#  6: 'Islam',
#  8: 'k'}

# %%
n = {
    "student_name" : ["jahid", "rayhan", "islam", "mamun"],
    "course_name" : "python",
    "topics" : { "python_basic" : "if_else",
                "basic_ds" : "list, tuple, set, dic",
                "opps" : "1,2,3"
                }
}

n["student_name"][3]
n["topics"]["python_basic"]
# Out:
# 'if_else'
