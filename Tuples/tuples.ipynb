# %%
t = (10,12,56,58,96,54,253,10,12,56)
type(t)
# Out:
# tuple

# %%
t.count(10)
# Out:
# 2

# %%
t.index(96)
# Out:
# 4

# %%
#Tuple modification
# age list kore then abar tuple korbo

# %%
l = list(t)
type(l)
# Out:
# list

# %%
print(l)
# Out:
# [10, 12, 56, 58, 96, 54, 253, 10, 12, 56]

# %%
l.append(100)
print(l)
# Out:
# [10, 12, 56, 58, 96, 54, 253, 10, 12, 56, 100]

# %%
t = list(l)
print(t)
# Out:
# [10, 12, 56, 58, 96, 54, 253, 10, 12, 56, 100]

# %%
# Nested touple

# %%
g = (12,56,56,54646,656,5,(456,6,85,6,4))
print(g[-1])
print(g[-1][2])
print(g[0:3])
# Out:
# (456, 6, 85, 6, 4)
# 85
# (12, 56, 56)

# %%
for i in g:
  print(i)
# Out:
# 12
# 56
# 56
# 54646
# 656
# 5
# (456, 6, 85, 6, 4)
