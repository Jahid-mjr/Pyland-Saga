# %%
s = {1,3,1,1,2,1,4,0,1,0}
print(s)
# Out:
# {0, 1, 2, 3, 4}

# %%
ss = {"cold", "appale", "vowel"}
ss
# Out:
# {'appale', 'cold', 'vowel'}

# %%
ss.add("aa")
ss
# Out:
# {'aa', 'appale', 'cold', 'vowel'}

# %%
t = (121,56,8,974,64,4)

ss.update(s)
ss.update(t)


ss
# Out:
# {0, 1, 121, 2, 3, 4, 5, 56, 64, 8, 974, 'aa', 'appale', 'cold', 'vowel'}

# %%
x = {12,56,36,85,6}

x.remove(12)
#x.remove(1)

x.discard(56)
#x.discard(1)

x
# Out:
# {6, 36, 85}

# %%
x.clear()
print(x)
# Out:
# set()

# %%
del x

# %%
a = {1,2,3}
b = {"a", "b"}
c = a.union(b)
#c = a | b
c
# Out:
# {1, 2, 3, 'a', 'b'}
